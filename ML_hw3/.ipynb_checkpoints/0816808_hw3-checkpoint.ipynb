# %% [markdown]
# # Assignment #3 - K-means Clustering & Support Vector Machine

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score
import prettytable
from scipy.spatial import distance
import random

# %% [markdown]
# # Wheat Seeds Dataset

# %% [markdown]
# ## Data Input

# %%
df=pd.read_csv('seeds_dataset.txt',delim_whitespace=True,header=None)
df.columns=['area','perimeter','compactness','length of kernel','width of kernel','asymmetry coefficient','length of kernel groove','label']
df
# Out:
#       area  perimeter  compactness  length of kernel  width of kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88       0.8511             5.140            2.795
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521             5.175            2.836
# 209  12.30      13.34       0.8684             5.243            2.974
#
#      asymmetry coefficient  length of kernel groove  label
# 0                    2.221                    5.220      1
# 1                    1.018                    4.956      1
# 2                    2.699                    4.825      1
# 3                    2.259                    4.805      1
# 4                    1.355                    5.175      1
# ..                     ...                      ...    ...
# 205                  3.631                    4.870      3
# 206                  4.325                    5.003      3
# 207                  8.315                    5.056      3
# 208                  3.598                    5.044      3
# 209                  5.637                    5.063      3
#
# [210 rows x 8 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Shuffle data

# %%
df=sklearn.utils.shuffle(df)
df
# Out:
#       area  perimeter  compactness  length of kernel  width of kernel  \
# 47   14.99      14.56       0.8883             5.570            3.377
# 199  12.76      13.38       0.8964             5.073            3.155
# 131  18.94      16.32       0.8942             6.144            3.825
# 187  10.91      12.80       0.8372             5.088            2.675
# 191  11.27      12.86       0.8563             5.091            2.804
# ..     ...        ...          ...               ...              ...
# 201  12.67      13.32       0.8977             4.984            3.135
# 142  13.34      13.95       0.8620             5.389            3.074
# 52   14.49      14.61       0.8538             5.715            3.113
# 43   15.50      14.86       0.8820             5.877            3.396
# 149  10.79      12.93       0.8107             5.317            2.648
#
#      asymmetry coefficient  length of kernel groove  label
# 47                   2.958                    5.175      1
# 199                  2.828                    4.830      3
# 131                  2.908                    5.949      2
# 187                  4.179                    4.956      3
# 191                  3.985                    5.001      3
# ..                     ...                      ...    ...
# 201                  2.300                    4.745      3
# 142                  5.995                    5.307      3
# 52                   4.116                    5.396      1
# 43                   4.711                    5.528      1
# 149                  5.462                    5.194      3
#
# [210 rows x 8 columns]

# %% [markdown]
# ### Build table

# %%
table1=prettytable.PrettyTable()
table1.field_names=['Wheat seed(K-means)','Accuracy','Recall','Precision']

# %% [markdown]
# ### split training and testing data

# %%
y = df['label'].values
x = df.drop(['label'], axis=1).values

# %% [markdown]
# ## K-means Clustering

# %%
#K-means clustering
k=3

# %%
train_num=x.shape[0]
feature_num=x.shape[1]

# %%
# 不確定這邊a b要不要改
def euclid_dis(a,b):
    return np.sqrt(np.sum((np.array(a)-np.array(b))**2))

# %%
def random_centroids(x,k):
    centroids_ini=[]
    index=np.random.randint(0,train_num-1,k)
    for i in index:
        centroids_ini.append(x[i])
    return np.array(centroids_ini)

# %%
centroids_ini=random_centroids(x,k)
# Out:
# (7,)

# %%
def Kmeans(points,centroids,k):
    #running until the centroids converage
    centroids_pre=np.zeros(centroids.shape)
    while True:
        #0:label refering to 1:distance
        clusters=np.zeros((train_num,2))
        clusters[:,0]=-1
        
        #assignment
        for i in range(train_num):
            distances=[]
            for j in range(k):
                distances.append(euclid_dis(x[i,:],centroids[j]))  #傳進去型態是numpy.array
            #c=np.argmin(distances)
            
            min_dis=min(distances)
            min_index=-1
            for n in distances:
                if n<min_dis:
                    min_dis=distance[n]
                    min_index=n
            if clusters[i,0]!=min_index:
                clusters[i,:]=min_index,min_dis
                    
        #update:find new centroids
        centroids_pre=copy.deepcopy(centroids)
        for j in range(k):
            point_in_cluster=x[[m for m in range(train_num) if clusters[x,0]==j]]
